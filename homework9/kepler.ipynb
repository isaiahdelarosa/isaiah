# %%
# File: Kepler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
ss = pd.read_csv("../../course_assignments/homework9/solar_system.csv") 
print("Shape:", ss.shape)
print("There are 20 rows and 11 columns.")
display(ss.head())
display(ss.tail())
print("Columns:", ss.columns.tolist())
# Out:
# Shape: (20, 11)
# There are 20 rows and 11 columns.
#                 Attribute Mercury  Venus  Earth   Moon   Mars Jupiter  Saturn  \
# 0          Mass (10^24kg)   0.330   4.87   5.97  0.073  0.642    1898     568
# 1           Diameter (km)    4879  12104  12756   3475   6792  142984  120536
# 2        Density (kg/m^3)    5429   5243   5514   3340   3934    1326     687
# 3         Gravity (m/s^2)     3.7    8.9    9.8    1.6    3.7    23.1     9.0
# 4  Escape Velocity (km/s)     4.3   10.4   11.2    2.4    5.0    59.5    35.5
#
#   Uranus Neptune   Pluto
# 0   86.8     102  0.0130
# 1  51118   49528    2376
# 2   1270    1638    1850
# 3    8.7    11.0     0.7
# 4   21.3    23.5     1.3
#                   Attribute Mercury Venus Earth Moon  Mars  Jupiter   Saturn  \
# 15     Mean Temperature (C)     167   464    15  -20   -65     -110     -140
# 16  Surface Pressure (bars)       0    92     1    0  0.01  Unknown  Unknown
# ...

# %%
# orbital_period = ss.loc['Orbital period'].astype(float)
perihelion = ss.loc['perihelion'].astype(float)
aphelion = ss.loc['Aphelion'].astype(float)

# Option B: if they are columns instead (common), uncomment and use:
# orbital_period = ss['Orbital_period'].astype(float)
# perihelion = ss['Perihelion'].astype(float)
# aphelion = ss['Aphelion'].astype(float)

# For safety, print a few values
# print("Orbital period (first 5):", orbital_period.head())
# print("Perihelion (first 5):", perihelion.head())
# print("Aphelion (first 5):", aphelion.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 2
#       1 # orbital_period = ss.loc['Orbital period'].astype(float)
# ----> 2 perihelion = ss.loc['perihelion'].astype(float)
#       3 aphelion = ss.loc['Aphelion'].astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# ...
